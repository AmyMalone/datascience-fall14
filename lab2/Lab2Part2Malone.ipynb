# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
countries = pd.read_csv('countries.csv')

# %%
players = pd.read_csv('players.csv')

# %%
events = pd.read_csv('events.csv')

# %%
players['name'].str.extract('(^[AEOIU])').count()
# Out:
# 84

# %%
players[(players['name'].str.startswith('A')) &  (players['country_id'] =='USA')]
# Out:
#                                         name   player_id country_id  \
# 1   Aaron Peirsol                             PEIRSAAR01        USA
# 3   Adam Nelson                               NELSOADA01        USA
# 15  Allyson Felix                             FELIXALL01        USA
# 16  Alvin Harrison                            HARRIALV01        USA
# 17  Amanda Beard                              BEARDAMA01        USA
# 18  Amanda Weir                               WEIRAMA01         USA
# 19  Amy van Dyken                             VANDYAMY01        USA
# 25  Angelo Taylor                             TAYLOANG02        USA
# 30  Anthony Ervin                             ERVINANT01        USA
# 32  Antonio Pettigrew                         PETTIANT01        USA
#
#      birthdate
# 1   1978-08-26
# 3   1984-10-13
# 15  1975-01-04
# 16  1976-05-15
# 17  1980-10-22
# 18  1979-01-09
# 19  1983-07-26
# 25  1974-08-24
# 30  1972-02-14
# 32  1976-03-21
#
# [10 rows x 4 columns]

# %%
join = pd.merge(players, countries, on='country_id')
result = join['name_y'].unique()
num_play = join.groupby('country_id').count()
right_frame = pd.DataFrame({'country_name': sorted(result), 'num_players': 
                            num_play['country_id']})

print right_frame
# Out:
#                                         country_name  num_players
# country_id
# ALG         Algeria                                             4
# ARG         Argentina                                           1
# AUS         Australia                                          34
# AUT         Austria                                             2
# BAH         Barbados                                            5
# BAR         Belarus                                             1
# BLR         Brazil                                              7
# BRA         Bulgaria                                            9
# BUL         Cameroon                                            1
# CAN         Canada                                              1
# CHN         China                                               8
# CMR         Costa Rica                                          1
# CRC         Croatia                                             1
# CRO         Cuba                                                1
# CUB         Czech Republic                                     12
# CZR         Denmark                                             3
# DEN         Dominican Republic                                  2
# DOM         Eritrea                                             1
# ERI         Estonia                                             1
# ESP         Ethiopia                                            4
# EST         Finland                                             2
# ETH         France                                             12
# FIN         Germany                                             1
# FRA         Greece                                             10
# GBR         Hungary                                            12
# GER         Iceland                                            22
# GRE         Ireland                                             7
# HUN         Italy                                               4
# IRL         Jamaica                                             1
# ISL         Japan                                               1
# ITA         Kazakhstan                                         12
# JAM         Kenya                                              18
# JPN         Latvia                                             16
# KAZ         Lithuania                                           2
# KEN         Mexico                                             13
# KSA         Morocco                                             1
# LAT         Mozambique                                          2
# LTU         Netherlands                                         2
# MAR         Nigeria                                             5
# MEX         Norway                                              3
# MOZ         Poland                                              1
# NED         Portugal                                           13
# NGR         Romania                                            12
# NOR         Russia                                              3
# POL         Saudi Arabia                                        5
# POR         Slovakia                                            3
# ROM         Slovenia                                           10
# RSA         South Africa                                       10
# RUS         Spain                                              38
# SLO         Sri Lanka                                           1
# SRI         Sweden                                              1
# SVK         The Bahamas                                         1
# SWE         Trinidad and Tobago                                 9
# TRI         Turkey                                              2
# TUR         Ukraine                                             1
# UKR         United Kingdom                                      9
# USA         United States                                      88
# ZIM         Zimbabwe                                            1
#
# [58 rows x 2 columns]

# %%
tempYr=players[players['birthdate'].str.contains('1975')]

table = pd.merge(countries, tempYr, left_index='country_id', right_index='country_id', how='outer')
table.groupby('country_id_y').count()

print  table
# Out:
#                                       name_x country_id_x  area_sqkm  \
# 0   Algeria                                           ALG    2381741
# 1   Argentina                                         ARG    2780400
# 2   Australia                                         AUS    7682300
# 3   Austria                                           AUT      83858
# 4   The Bahamas                                       BAH      13878
# 5   Barbados                                          BAR        430
# 6   Belarus                                           BLR     207600
# 7   Brazil                                            BRA    8514877
# 8   Bulgaria                                          BUL     110912
# 9   Canada                                            CAN    9970610
# 10  China                                             CHN    9596961
# 11  Cameroon                                          CMR     475442
# 12  Costa Rica                                        CRC      51100
# 13  Croatia                                           CRO      56538
# 14  Cuba                                              CUB     110861
# 15  Czech Republic                                    CZR      78866
# 16  Denmark                                           DEN      43094
# 17  Dominican Republic                                DOM      48671
# 18  Eritrea                                           ERI     117600
# 19  Spain                                             ESP     506030
# 20  Estonia                                           EST      45100
# 21  Ethiopia                                          ETH    1104300
# 22  Finland                                           FIN     338145
# 23  France                                            FRA     551500
# 24  United Kingdom                                    GBR     242900
# 25  Germany                                           GER     357022
# 26  Greece                                            GRE     131957
# 27  Hungary                                           HUN      93032
# 28  Ireland                                           IRL      70273
# 29  Iceland                                           ISL     103000
# 30  Italy                                             ITA     301318
# 31  Jamaica                                           JAM      10991
# 32  Japan                                             JPN     377873
# 33  Kazakhstan                                        KAZ    2724900
# 34  Kenya                                             KEN     580367
# 35  Saudi Arabia                                      KSA    2149690
# 36  Latvia                                            LAT      64600
# 37  Lithuania                                         LTU      65300
# 38  Morocco                                           MAR     446550
# 39  Mexico                                            MEX    1958201
# 40  Mozambique                                        MOZ     801590
# 41  Netherlands                                       NED      41528
# 42  Nigeria                                           NGR     923768
# 43  Norway                                            NOR     385155
# 44  Poland                                            POL     312685
# 45  Portugal                                          POR      91982
# 46  Romania                                           ROM     238391
# 47  South Africa                                      RSA    1221037
# 48  Russia                                            RUS   17098242
# 49  Slovenia                                          SLO      20256
# 50  Sri Lanka                                         SRI      65610
# 51  Slovakia                                          SVK      49033
# 52  Sweden                                            SWE     449964
# 53  Trinidad and Tobago                               TRI       5130
# 54  Turkey                                            TUR     783562
# 55  Ukraine                                           UKR     603700
# 56  United States                                     USA    9629091
# 57  Zimbabwe                                          ZIM     390757
# 82                                       NaN          NaN        NaN
# 84                                       NaN          NaN        NaN
#                                          ...          ...        ...
#
#     population                                    name_y   player_id  \
# 0     32853800                                       NaN         NaN
# 1     38747150                                       NaN         NaN
# 2     21050000                                       NaN         NaN
# 3      8189444                                       NaN         NaN
# 4       323063                                       NaN         NaN
# 5       269556  Ai Shibata                                SHIBAAI01
# 6      9755106                                       NaN         NaN
# 7    186404900                                       NaN         NaN
# 8      7725965                                       NaN         NaN
# 9     33390141  Aleksander Tammert                        TAMMEALE01
# 10  1323324000                                       NaN         NaN
# 11    16321860                                       NaN         NaN
# 12     4327228                                       NaN         NaN
# 13     4551338                                       NaN         NaN
# 14    11269400  Alice Mills                               MILLSALI01
# 15    10403136  Allyson Felix                             FELIXALL01
# 16     5471590                                       NaN         NaN
# 17     9365818                                       NaN         NaN
# 18     4401357                                       NaN         NaN
# 19    45200737                                       NaN         NaN
# 20     1329697                                       NaN         NaN
# 21    77430700                                       NaN         NaN
# 22     5302060                                       NaN         NaN
# 23    60495540                                       NaN         NaN
# 24    60776238                                       NaN         NaN
# 25    82689210                                       NaN         NaN
# 26    11119890                                       NaN         NaN
# 27    10097730                                       NaN         NaN
# 28     4147901                                       NaN         NaN
# 29      309672                                       NaN         NaN
# 30    58092740                                       NaN         NaN
# 31     2650713                                       NaN         NaN
# 32   128084700                                       NaN         NaN
# 33    14825110                                       NaN         NaN
# 34    34255720                                       NaN         NaN
# 35    24573100                                       NaN         NaN
# 36     2306988                                       NaN         NaN
# 37     3369600                                       NaN         NaN
# 38    31478460                                       NaN         NaN
# 39   107029400                                       NaN         NaN
# 40    19792300                                       NaN         NaN
# 41    16423431                                       NaN         NaN
# 42   131529700                                       NaN         NaN
# 43     4751236                                       NaN         NaN
# 44    38529560                                       NaN         NaN
# 45    10494500                                       NaN         NaN
# 46    21711470                                       NaN         NaN
# 47    47431830                                       NaN         NaN
# 48   143201600                                       NaN         NaN
# 49     2066814                                       NaN         NaN
# 50    20742910                                       NaN         NaN
# 51     5400908                                       NaN         NaN
# 52     9041262  Calvin Harrison                           HARRICAL01
# 53     1305236                                       NaN         NaN
# 54    70586256  Carlos Jayme                              JAYMECAR01
# 55    46480700                                       NaN         NaN
# 56   301140000  Carolina Kluft                            KLUFTCAR01
# 57    13009530                                       NaN         NaN
# 82         NaN  Danny McFarlane                           MCFARDAN01
# 84         NaN  Dara Torres                               TORREDAR01
#            ...                                       ...         ...
#
#    country_id_y   birthdate
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           JPN  1975-11-22
# 6           NaN         NaN
# 7           NaN         NaN
# 8           NaN         NaN
# 9           EST  1975-01-10
# 10          NaN         NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN         NaN
# 14          AUS  1975-02-17
# 15          USA  1975-01-04
# 16          NaN         NaN
# 17          NaN         NaN
# 18          NaN         NaN
# 19          NaN         NaN
# 20          NaN         NaN
# 21          NaN         NaN
# 22          NaN         NaN
# 23          NaN         NaN
# 24          NaN         NaN
# 25          NaN         NaN
# 26          NaN         NaN
# 27          NaN         NaN
# 28          NaN         NaN
# 29          NaN         NaN
# 30          NaN         NaN
# 31          NaN         NaN
# 32          NaN         NaN
# 33          NaN         NaN
# 34          NaN         NaN
# 35          NaN         NaN
# 36          NaN         NaN
# 37          NaN         NaN
# 38          NaN         NaN
# 39          NaN         NaN
# 40          NaN         NaN
# 41          NaN         NaN
# 42          NaN         NaN
# 43          NaN         NaN
# 44          NaN         NaN
# 45          NaN         NaN
# 46          NaN         NaN
# 47          NaN         NaN
# 48          NaN         NaN
# 49          NaN         NaN
# 50          NaN         NaN
# 51          NaN         NaN
# 52          USA  1975-11-27
# 53          NaN         NaN
# 54          BRA  1975-10-01
# 55          NaN         NaN
# 56          SWE  1975-12-02
# 57          NaN         NaN
# 82          JAM  1975-10-27
# 84          USA  1975-07-07
#             ...         ...
#
# [83 rows x 8 columns]
